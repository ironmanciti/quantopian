# %% [markdown]
# # Chapter 1. Jupyter Notebook Crash

# %% [markdown]
# ### Code Cells vs. Text Cells
# ### Executing a Command

# %%
2 + 2
# Out:
# 4

# %%
X = 2

# %%
2 + 2
3 + 3
# Out:
# 6

# %%
print(2 + 2)
3 + 3
# Out:
# 4
# 6

# %%
# %%timeit
c = 0
for i in range(10000000):
    c = c + i
# Out:
# 550 ms ± 28.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# ### Tab Autocomplete

# %%
np.random.normal?

# %% [markdown]
# ### Sampling

# %%
X = np.random.normal(0, 1, 100)

# %%
plt.plot(X)

# %%
X = np.random.normal(0, 1, 100)
X2 = np.random.normal(0, 1, 100)

plt.plot(X);
plt.plot(X2);
plt.xlabel('Time') # The data we generated is unitless, but don't forget units in general.
plt.ylabel('Returns')
plt.legend(['X', 'X2']);

# %%
np.mean(X)
# Out:
# 0.15890395256183443

# %%
np.std(X)
# Out:
# 0.9368154091714553

# %%
import quandl
quandl.ApiConfig.api_key = 'U_Gp39gZutpHmaFgC65Y' 

data = quandl.get('WIKI/MSFT', start_date='2012-01-01', end_date='2015-06-01')

# %%
data.head()
# Out:
#                Open    High     Low   Close      Volume  Ex-Dividend  \
# Date
# 2012-01-03  26.5500  26.960  26.390  26.765  64731500.0          0.0
# 2012-01-04  26.8199  27.470  26.780  27.400  80516100.0          0.0
# 2012-01-05  27.3800  27.728  27.290  27.680  56081400.0          0.0
# 2012-01-06  27.5300  28.190  27.525  28.105  99455500.0          0.0
# 2012-01-09  28.0500  28.100  27.720  27.740  59706800.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2012-01-03          1.0  22.609162  22.958305  22.472910   22.792249
# 2012-01-04          1.0  22.839000  23.392605  22.805022   23.332995
# 2012-01-05          1.0  23.315964  23.612310  23.239323   23.571435
# 2012-01-06          1.0  23.443699  24.005735  23.439442   23.933352
# 2012-01-09          1.0  23.886515  23.929094  23.605497   23.622529
#
#             Adj. Volume
# Date
# 2012-01-03   64731500.0
# 2012-01-04   80516100.0
# 2012-01-05   56081400.0
# ...

# %%
X = data['Close']

# %%
plt.plot(X.index, X.values)
plt.ylabel('Price')
plt.legend(['MSFT']);

# %%
np.mean(X)
# Out:
# 36.06461038506418

# %%
np.std(X)
# Out:
# 6.698306657964224

# %% [markdown]
# ### Getting Returns from Prices

# %%
R = X.pct_change()[1:]

# %%
plt.hist(R, bins=20)
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['MSFT Returns']);

# %%
np.mean(R)
# Out:
# 0.0007678571094289014

# %%
np.std(R)
# Out:
# 0.01442121547507862

# %%
plt.hist(np.random.normal(np.mean(R), np.std(R), 10000), bins=20)
plt.xlabel('Return')
plt.ylabel('Frequency')
plt.legend(['Normally Distributed Returns']);

# %% [markdown]
# 이제 Microsoft의 수익에서 추정 한 통계를 사용하여 정규 분포에 따른 데이터를 생성 해 봅시다. 구 그래프의 결과가 크게 다르므로 Microsoft의 수익률이 정규분포를 따르지 않을 수 있다고 의심할만한 이유가 있음을 알게 될 것입니다.

# %% [markdown]
# ### Generating a Moving Average

# %%
MAVG = pd.rolling_mean(X, window=60)
plt.plot(X.index, X.values)
plt.plot(MAVG.index, MAVG.values)
plt.ylabel('Price')
plt.legend(['MSFT', '60-day MAVG']);
# Out:
# C:\Users\trimu\Miniconda3\envs\py36_64\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=60,center=False).mean()
#   """Entry point for launching an IPython kernel.
